# %% [markdown]
# <a href="https://colab.research.google.com/github/a95123hsu/IST526-Assignment5/blob/main/Question_6_Sankey_diagram_as_closely_as_possible.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python visualization libraries
import pandas as pd
import numpy as np

import math
import json


import plotly.express as px
import plotly.graph_objects as go

# for hierarchical data
import networkx as nx
import os

from google.colab import drive
drive.mount('/content/drive')

# edit this path if needed
my_path = '/content/drive/My Drive/Colab Notebooks/'

# change to this path
os.chdir(my_path)

# verify present working directory. It should be identical to 'my_path'
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = ["Automotive Sales $18.9B", "Automotive Leasing $564M","Automotive Regulatory Credits $521M","Energy Generation and Storage $1.5B", "Services and Other $1.8B", "Total Revenue $23.3B", "Gross Profit $4.5B", "Interest Income $213M","Net Income $2.5B","Operating Income $2.7B","Operating Expenses $1.8B","Cost of Revenue $18.8B","Interest Expense $29M", "Tax & Other Expense $1.8B","SG&A $1.1B","R&D $771M" ],
      color = "blue"
    ),
    link = dict(
      source = [5,0,1,2,3,4,5,6,8,9,9,9,6,10,10], # indices correspond to labels, eg A1, A2, A1, B1, ...
      target = [11,5,5,5,5,5,6,10,7,13,12,8,9,14,15],
      value = [18800,18900,564,521,1500,1800,4500,1800,213,309,29,2500,2700,1100,771]
  ))])

fig.update_layout(title_text="Tesla Stock (Values in Millions)", font_size=15)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# After hovering the roots:
# ![螢幕擷取畫面 2023-05-04 060702.png](data:image/png;base64,...)
